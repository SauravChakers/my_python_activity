# %%
#All instances of violations of PEP8 are in square brackets [] in the same line as the code where the violation occurs.


# Program To Make Simple Calculator [full stop missing at end of sentence]
# This function adds 2numbers [missing space in 2numbers; fullstop missing at end of sentence; no linebreak] 
def add( x, y ): [add two empty lines infront of function definition; incorrect use of spacing between brackets and variables]
    return x + y

#This function subtracts  2numbers [missing space in 2numbers; inconsistent spacing; fullstop missing]
def subtract(x, y): [add two empty lines infront of function definition]
    return x - y


[excessive line break; remove 2 lines above]
       #This function multipliers 2numbers [indentation not required; functional description unclear; same problem with
missing space in 2numbers; fullstop missing]
def multiply(x, y):[add two empty lines infront of function definition]
   return x * y [incorrect indentation; needs to be 4, not 3 spaces]

##This function divides  2numbers # [excessive use of #; missing space in 2numbers; missing fullstop at end of sentence]
def divide(x, y): [add two empty lines infront of function definition]
   return x / y [incorrect indentation; needs to be 4, not 3 spaces]

print ( "Select operation.") [incorrect use of space between (); incorrect use of fullstop;]
print ( "1.Add") [same as above and wrong use of Add vs add;]
print ( "2.Subtract") [same as above; wrong use of Subtract v subtract;]
print ( "3.Multiply") [same as above; wrong use of Multiply vs multiply;]
print ( "4.Divide") [same as above; wrong use of Divide vs divide;]

while True: [check indentation]
[incorrect use of space; not required]   
   choice = input  ("Enter choice(1/2/3/4): ")# Take input from the  user [insufficient indentation; incorrect use of space 
before (); Comment on same line: should have been seperate line; missing fullstop at end of comment]

   # Check if choice is 1 of the four options by completing the following code in the IDE of your choice or noteboolk 
    [indentation for comment not required; inconsistent use of numbers: 1 vs four; IDE should be defined; spelling mistake 
in noteboolk; missing fullstop at end of comment; comment greater than 79 characters]
   if choice in ('1', '2', '3', '4'): [incorrect use of indentation; should be 4 spaces]
      Num1   = float(input("Enter first number: ")) [incorrect use of indentation; incorrect use of space either side of =]
      Num2   = float(input("Enter second number: ")) [same as above]
[incorrect use of line break; not required]
       if CHOICE == '1': [incorrect use of indentation leading to fatal error here; CHOICE not defined]
           print(Num1, "+", Num2, "=", add( Num1, Num2 )) [incorrect use of indentation, "" not required; , not required]
[incorrect use of line break; not required]
       elif CHOICE == '2': [incorrect use of indentation leading to fatal error here; CHOICE not defined]
           print (Num1, "-", Num2, "=", subtract( Num1, Num2 ))[incorrect use of indentation, "" not required; , not required]
[incorrect use of line break; not required]
       elif CHOICE == '3':[incorrect use of indentation leading to fatal error here; CHOICE not defined]
           print (Num1, "*", Num2, "=", multiply( Num1, Num2 ))[incorrect use of indentation, "" not required; , not required]
[incorrect use of line break; not required]
       elif CHOICE == '4':[incorrect use of indentation leading to fatal error here; CHOICE not defined]
           print (Num1, "/", Num2, "=", divide( Num1, Num2 ))[incorrect use of indentation, "" not required; , not required]
       break [at least 2 line breaks required here; incorrect indentation; not sure the code from here on is required.]
   else: [incorrect indentation]
[line break not required]
       Print( "Invalid Input" )#this prints the invalid input.... [incorrect indentation; space not required between ();
incorrect use of capital letter in Print; comment should be on seperate line; poor formatting of comments; comment not req'd.]

# %%
# Program To Make Simple Calculator.


# This function adds two numbers.


def add(x, y):
    return x + y


#This function subtracts two numbers.


def subtract(x, y):
    return x - y


#This function multiplies two numbers.


def multiply(x, y):
    return x * y


#This function divides two numbers.


def divide(x, y):
    return x / y


print ("Select operation")
print ("1.add")
print ("2.subtract")
print ("3.multiply")
print ("4.divide")


while True:
    choice = input ("Enter choice(1 / 2 / 3 / 4): ")

# Take input from the user.
# Check if choice is one of 4 above by completing the following code in the IDE or notebook.


    if choice in ('1', '2', '3', '4'):
        Num1 = float(input("Enter first number: "))
        Num2 = float(input("Enter second number: "))
        if choice == '1':
            print(Num1, "+", Num2, "=", add( Num1, Num2 ))
        elif choice == '2':
            print (Num1, "-", Num2, "=", subtract( Num1, Num2 ))
        elif choice == '3':
            print (Num1, "*", Num2, "=", multiply( Num1, Num2 ))
        elif choice == '4':
            print (Num1, "/", Num2, "=", divide( Num1, Num2 ))
# Out:
# Select operation
# 1.add
# 2.subtract
# 3.multiply
# 4.divide
